# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Cargar datos
df = pd.read_csv('dato.csv',  sep = ";")

#a_1 and i_1
a_1 = df['a_1']
i_1 = df['i_1']

# a_2 and i_2
a_2 = df['a_2']
i_2 = df['i_2']

# a_3 and i_3
a_3 = df['a_3']
i_3 = df['i_3']

# a_4 and i_4
a_4 = df['a_4']
i_4 = df['i_4']

# a_5 and i_5
a_5 = df['a_5']
i_5 = df['i_5']

# a_6 and i_6
a_6 = df['a_6']
i_6 = df['i_6']

# a_7 and i_7
a_7 = df['a_7']
i_7 = df['i_7']

# a_8 and i_8
a_8 = df['a_8']
i_8 = df['i_8']

# a_9 and i_9
a_9 = df['a_9']
i_9 = df['i_9']

# a_10 and i_10
a_10 = df['a_10']
i_10 = df['i_10']

# a_11 and i_11
a_11 = df['a_11']
i_11 = df['i_11']

#intervalo
a = 2
b = 9

#plot all
plt.plot(a_1[(a_1>a) & (a_1<b)], i_1[(a_1>a) & (a_1<b)], 'k.', label = '1')
plt.plot(a_2[(a_2>a) & (a_2<b)], i_2[(a_2>a) & (a_2<b)], 'b.', label = '2')
plt.plot(a_3[(a_3>a) & (a_3<b)], i_3[(a_3>a) & (a_3<b)], 'r.', label = '3')
plt.plot(a_4[(a_4>a) & (a_4<b)], i_4[(a_4>a) & (a_4<b)], 'g.', label = '4')
plt.plot(a_5[(a_5>a) & (a_5<b)], i_5[(a_5>a) & (a_5<b)], 'm.', label = '5')
plt.plot(a_6[(a_6>a) & (a_6<b)], i_6[(a_6>a) & (a_6<b)], 'c.', label = '6')
plt.plot(a_7[(a_7>a) & (a_7<b)], i_7[(a_7>a) & (a_7<b)], 'y.', label = '7')
plt.plot(a_8[(a_8>a) & (a_8<b)], i_8[(a_8>a) & (a_8<b)], 'k.', label = '8')
plt.plot(a_9[(a_9>a) & (a_9<b)], i_9[(a_9>a) & (a_9<b)], 'b.', label = '9')
plt.plot(a_10[(a_10>a) & (a_10<b)], i_10[(a_10>a) & (a_10<b)], 'r.', label = '10')
plt.plot(a_11[(a_11>a) & (a_11<b)], i_11[(a_11>a) & (a_11<b)], 'g.', label = '11')
plt.show()
