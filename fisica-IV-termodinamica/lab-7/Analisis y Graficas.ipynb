# %%
import numpy as np
import matplotlib.pyplot as plt

# Valor teórico de la constante J
valor_teorico = 4.18

#DATOS



calor_absorbido_exp1 = [216.5448, 433.0896, 649.6344, 866.1792, 1082.724, 1299.2688, 1515.8136, 1732.3584, 1948.9032, 2165.448, 2381.9928, 2598.5376, 2815.0824]
energia_transferida_exp1 = [365.1823716, 871.691124, 1386.497448, 2281.564526, 3146.831724, 4307.688757, 5283.501022, 6169.199874, 7409.731439, 8716.91124, 9877.232946, 10838.41293, 11806.73062]

calor_absorbido_exp2 = [611.7144, 815.6192, 1019.524, 1223.4288, 1427.3336, 1631.2384, 1835.1432, 2039.048, 2242.9528, 2446.8576]
energia_transferida_exp2 = [187.1018324, 1106.357515, 1891.381878, 2935.247568, 3737.926573, 4524.912563, 5519.644172, 6467.57697, 7495.376003, 8443.682444]

calor_absorbido_exp3 = [202.5348, 405.0696, 607.6044, 810.1392, 1012.674, 1215.2088, 1417.7436, 1620.2784, 1822.8132, 2025.348]
energia_transferida_exp3 = [231.5712312, 773.2903212, 1464.611431, 2249.721077, 2993.900837, 4484.55856, 5123.896524, 5953.000327, 6681.20211, 7669.976247]

calor_absorbido_exp4 = [189.3722, 378.7444, 568.1166, 757.4888, 946.861, 1136.2332, 1325.6054, 1514.9776, 1704.3498, 1893.722]
energia_transferida_exp4 = [344.7340819, 667.171063, 1219.3727, 1714.786408, 2187.903016, 2872.667885, 3748.525876, 4454.368473, 5586.991515, 6673.975179]

# %%
#EXP 1

fig, ax = plt.subplots()

# Regresión lineal
coeffs = np.polyfit(calor_absorbido_exp1, energia_transferida_exp1, 1)
a = coeffs[0]
b = coeffs[1]
linea_ajuste = a * np.array(calor_absorbido_exp1) + b


# Calcular la constante J experimental
J_experimental_exp1 = a

error_porcentual_exp1 = abs(J_experimental_exp1 - valor_teorico) / valor_teorico * 100

print("Constante J experimental 1:", J_experimental_exp1)
print("Error porcentual:", error_porcentual_exp1)

#Grafico
ax.plot(calor_absorbido_exp1, energia_transferida_exp1, 'ro', label='Datos experimentales')
ax.plot(calor_absorbido_exp1, linea_ajuste, 'k-', label='Ajuste lineal')

ax.set_title('Experimento 1')
ax.set_xlabel('Calor absorbido (ΔQ) [cal]')
ax.set_ylabel('Energía transferida (E) [J]')

ax.legend()

plt.show()
# Out:
# Constante J experimental 1: 4.621513824487494
# Error porcentual: 10.562531686303682

# %%
#EXP 2
fig, ax = plt.subplots()

# Regresión lineal
coeffs = np.polyfit(calor_absorbido_exp2, energia_transferida_exp2, 1)
a = coeffs[0]
b = coeffs[1]
linea_ajuste = a * np.array(calor_absorbido_exp2) + b


# Calcular la constante J experimental
J_experimental_exp2 = a

error_porcentual_exp2 = abs(J_experimental_exp2 - valor_teorico) / valor_teorico * 100

print("Constante J experimental 2:", J_experimental_exp2)
print("Error porcentual:", error_porcentual_exp2)

#Grafico
ax.plot(calor_absorbido_exp2, energia_transferida_exp2, 'ro', label='Datos experimentales')
ax.plot(calor_absorbido_exp2, linea_ajuste, 'k-', label='Ajuste lineal')

ax.set_title('Experimento 2')
ax.set_xlabel('Calor absorbido (ΔQ) [cal]')
ax.set_ylabel('Energía transferida (E) [J]')

ax.legend()

plt.show()
# Out:
# Constante J experimental 2: 4.471888015429186
# Error porcentual: 6.9829668762963175

# %%
#EXP 3
fig, ax = plt.subplots()

# Regresión lineal
coeffs = np.polyfit(calor_absorbido_exp3, energia_transferida_exp3, 1)
a = coeffs[0]
b = coeffs[1]
linea_ajuste = a * np.array(calor_absorbido_exp3) + b


# Calcular la constante J experimental
J_experimental_exp3 = a

error_porcentual_exp3 = abs(J_experimental_exp3 - valor_teorico) / valor_teorico * 100

print("Constante J experimental 3:", J_experimental_exp3)
print("Error porcentual:", error_porcentual_exp3)

#Grafico
ax.plot(calor_absorbido_exp3, energia_transferida_exp3, 'ro', label='Datos experimentales')
ax.plot(calor_absorbido_exp3, linea_ajuste, 'k-', label='Ajuste lineal')

ax.set_title('Experimento 3')
ax.set_xlabel('Calor absorbido (ΔQ) [cal]')
ax.set_ylabel('Energía transferida (E) [J]')

ax.legend()

plt.show()
# Out:
# Constante J experimental 3: 4.214948117492237
# Error porcentual: 0.8360793658429965

# %%
#EXP 4
fig, ax = plt.subplots()

# Regresión lineal
coeffs = np.polyfit(calor_absorbido_exp4, energia_transferida_exp4, 1)
a = coeffs[0]
b = coeffs[1]
linea_ajuste = a * np.array(calor_absorbido_exp4) + b


# Calcular la constante J experimental
J_experimental_exp4 = a

error_porcentual_exp4 = abs(J_experimental_exp4 - valor_teorico) / valor_teorico * 100

print("Constante J experimental 4:", J_experimental_exp4)
print("Error porcentual:", error_porcentual_exp4)

#Grafico
ax.plot(calor_absorbido_exp4, energia_transferida_exp4, 'ro', label='Datos experimentales')
ax.plot(calor_absorbido_exp4, linea_ajuste, 'k-', label='Ajuste lineal')

ax.set_title('Experimento 4')
ax.set_xlabel('Calor absorbido (ΔQ) [cal]')
ax.set_ylabel('Energía transferida (E) [J]')

ax.legend()

plt.show()
# Out:
# Constante J experimental 4: 3.660032118755519
# Error porcentual: 12.439422996279445

# %%
# Constantes J experimentales
J_experimentales = [J_experimental_exp1, J_experimental_exp2, J_experimental_exp3, J_experimental_exp4]

# Promedio de las constantes J experimentales
promedio_J = np.mean(J_experimentales)

# Error porcentual
error_porcentual = abs(promedio_J - valor_teorico) / valor_teorico * 100

# Mostrar el resultado en pantalla
print("Promedio de las constantes J experimentales:", promedio_J)
print("Error porcentual respecto del valor teórico:", error_porcentual)
# Out:
# Promedio de las constantes J experimentales: 4.24209551904111
# Error porcentual respecto del valor teórico: 1.4855387330409064
